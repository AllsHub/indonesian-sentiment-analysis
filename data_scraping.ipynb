# %%
import csv
import pandas as pd
from google_play_scraper import app, reviews, Sort, reviews_all

# %%
scrapreview, _ = reviews(
    'com.tokopedia.tkpd',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=25000
)

# %%
with open('ulasan_aplikasi.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])
    for review in scrapreview:
        writer.writerow([review['content']])

app_reviews_df = pd.DataFrame(scrapreview)

print(f"Total data: {len(app_reviews_df)}")
# Out:
# Total data: 25000

# %%
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  c817394a-35d3-40fc-98af-20ff06844832  Pengguna Google
# 1  5df23897-066b-4b12-a4b6-8d65edfbb630  Pengguna Google
# 2  8ca2b198-694d-41c9-9b46-73c0410bd3d2  Pengguna Google
# 3  a130b75b-ffee-4c09-b590-cc8384fc98a2  Pengguna Google
# 4  87192777-615b-41ff-ad57-008cf627777c  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Dulu si orange yg berat, skrg kebalik si ijo y...      1             28
# 1  sulit buat retur barang, udah mengajukan penge...      1             49
# 2  akhirnya hapus akun dan hapus aplikasi tidak r...      1              9
# 3  lebih baik beli di shoppe aja, Tokopedia banya...      1             63
# 4  males belanja di toped ketika ada barang yg ti...      1             66
#
#   reviewCreatedVersion                  at  \
# 0              3.331.1 2025-09-26 21:58:36
# 1              3.330.0 2025-09-22 11:18:20
# 2              3.331.1 2025-09-29 18:07:11
# 3              3.329.0 2025-09-13 13:37:18
# 4              3.329.0 2025-09-10 06:57:12
#
#                                         replyContent           repliedAt  \
# 0                                               None                 NaT
# 1                                               None                 NaT
# 2                                               None                 NaT
# 3                                               None                 NaT
# 4  Halo Toppers, terima kasih atas rating yang ka... 2024-11-01 06:40:04
#
#   appVersion
# 0    3.331.1
# 1    3.330.0
# 2    3.331.1
# 3    3.329.0
# 4    3.329.0

# %%
app_reviews_df.to_csv('ulasan_aplikasi.csv', index=False)
